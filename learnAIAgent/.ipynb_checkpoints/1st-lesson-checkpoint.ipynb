# %%
from langchain_ollama import ChatOllama
import time

# %%
# llm1 = ChatOllama(model="llama3")
llm2 = ChatOllama(model="mistral")

# %%
# response1 =  llm1.invoke("What is weather")
# print(response1)

# %%
t1 = time.time()
response2 =  llm2.invoke("What is weather")
print(response2)
t2 = time.time()
print(f"Time taken: {t2 - t1}")
# Out:
# content=' Weather refers to the short-term atmospheric conditions in a specific place, including temperature, humidity, air pressure, wind speed and direction, precipitation, and cloud cover. It can change rapidly over hours or days and is different from climate, which is the long-term average of weather patterns over a period of at least 30 years. Weather is influenced by many factors, such as solar radiation, temperature differences between water and land, air pressure systems, and geographical features like mountains and oceans. It can have significant impacts on human activities and ecosystems.' additional_kwargs={} response_metadata={'model': 'mistral', 'created_at': '2026-04-03T16:09:34.629866608Z', 'done': True, 'done_reason': 'stop', 'total_duration': 66327091854, 'load_duration': 7289644759, 'prompt_eval_count': 7, 'prompt_eval_duration': 3017241333, 'eval_count': 121, 'eval_duration': 55720101852, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'} id='lc_run--019d541a-6189-7891-9b4d-eb56468964eb-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 121, 'total_tokens': 128}
# Time taken: 66.3775110244751

# %%
print(response2.content)
# Out:
#  Weather refers to the short-term atmospheric conditions in a specific place, including temperature, humidity, air pressure, wind speed and direction, precipitation, and cloud cover. It can change rapidly over hours or days and is different from climate, which is the long-term average of weather patterns over a period of at least 30 years. Weather is influenced by many factors, such as solar radiation, temperature differences between water and land, air pressure systems, and geographical features like mountains and oceans. It can have significant impacts on human activities and ecosystems.

# %% [markdown]
# # TOOLS

# %%
def calc_tool(query):
    return str(eval(query))

# %%
def simple_agent(user_input):

    decision_prompt = f"""You are a helpful AI agent assistant. 
    You will be given a user input and you need to decide if you 
    should use the calculator tool or respond directly.

    If calculator tool is needed, respond with "use calculator: <calculation query>"
    
    If calculator tool is not needed, respond with "respond directly: <your response>"
    User input: {user_input}
    """

    decision_response = llm2.invoke(decision_prompt).content.strip()
    if decision_response.startswith("use calculator:"):
        calc_query = decision_response.replace("use calculator:", "").strip()
        calc_result = calc_tool(calc_query)
        return f"Calculator result: {calc_result}"
    elif decision_response.startswith("respond directly:"):
        direct_response = decision_response.replace("respond directly:", "").strip()
        return f"Direct response: {direct_response}"
    else:
        return "Invalid response from agent."

# %%
print (simple_agent("what is weather"))
# Out:
# Invalid response from agent.

# %%
print (simple_agent("12 * 12"))
# Out:
# Direct response: The product of 12 and 12 is 144.

# %%
print (simple_agent("calculate 45 * 23"))
# Out:
# Invalid response from agent.
